# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('E:/Research_Files/JVG.csv')
X = data.iloc[:, :-1].values
y = data.iloc[:, 1].values
data.head()
# Out:
#   Junction Type  Griev
# 0         Not-J     45
# 1         Cross      8
# 2         T/Jun     18
# 3         StagX      0
# 4         Round      1

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
type_mapping = {'Not-J': 1, 'Cross': 2, 'T/Jun': 3, 'StagX': 4, 'Round': 5, 'RailW': 6, 'Other': 7}

# %%
data['Junction Type'] = data['Junction Type'].map(type_mapping)

# %%
X = data[['Junction Type']]
y = data['Griev']

# %%
model.fit(X, y)
# Out:
# LinearRegression()

# %%
predicted_total_incidents = model.predict([[1]])
print("Predicted Griev incidents for Junction Type Not-J:", predicted_total_incidents[0])
# Out:
# Predicted Griev incidents for Junction Type Not-J: 25.229591836734695
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
plt.scatter(X, y, color='blue', label='Data Points')

plt.plot(X, model.predict(X), color='red', label='Linear Regression Line')
# Adding labels and title
plt.xlabel('Junction Type (Numerical)')
plt.ylabel('Total Number of Griev Incidents')
plt.title('Scatter Plot: Griev Incidents vs. Junction Type')

# Showing the plot
plt.legend()
plt.grid(True)
plt.show()
